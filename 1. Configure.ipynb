# %%
'''
You need to set 1 variable. You do not need to execute these cells. The other notebooks are going to call this notebook

Set this variable to a unique value different from anyone else in your workshop. Example would be <lastname_firstname>
my_database = echevarria_mike
'''
my_database = "mag_workshop"

# %%
# This cell will display in the other notebooks to let you know which database/schema you are writing to
print(f"Your schema/database:\nmy_database={my_database}")
# Out:
# Your schema/database:
# my_database=mag_workshop
